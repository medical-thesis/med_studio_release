# %%
# !pip install pandas numpy nltk rouge-score bert-score sentence-transformers scikit-learn pycocoevalcap torch transformers

# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
from collections import Counter

model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')


def word_f1(pred, gt):
    """Tính F1 score dựa trên từ"""
    pred_tokens = set(pred.lower().split())
    gt_tokens = set(gt.lower().split())

    common = pred_tokens & gt_tokens
    if len(pred_tokens) == 0 or len(gt_tokens) == 0:
        return 0.0

    precision = len(common) / len(pred_tokens)
    recall = len(common) / len(gt_tokens)

    if (precision + recall) == 0:
        return 0.0

    return 2 * (precision * recall) / (precision + recall)


def context_relevance(context, answer):
    """Tính độ liên quan giữa ngữ cảnh và câu trả lời (0-1)"""
    if not context or not answer:
        return 0.0
    context_emb = model.encode(context)
    answer_emb = model.encode(answer)
    return cosine_similarity([context_emb], [answer_emb])[0][0]


def answer_relevance(question, answer):
    """Tính độ liên quan giữa câu hỏi và câu trả lời (0-1)"""
    if not question or not answer:
        return 0.0
    q_emb = model.encode(question)
    a_emb = model.encode(answer)
    return cosine_similarity([q_emb], [a_emb])[0][0]


def diversity_score(text):
    """Tính độ đa dạng từ vựng (tỷ lệ từ duy nhất/tổng số từ)"""
    tokens = text.lower().split()
    if not tokens:
        return 0.0
    unique_tokens = set(tokens)
    return len(unique_tokens) / len(tokens)


def evaluate_rag_simple(data):
    """Hàm chính để đánh giá hệ thống RAG"""
    results = []

    for item in data:
        pred = item.get("answer", "")
        ref = item.get("ground_truth", "")
        context = item.get("contexts", [""])[0]
        question = item.get("question", "")

        metrics = {
            "Question": question,
            # "Word F1": word_f1(pred, ref),
            "Context Relevance": context_relevance(context, pred),
            "Answer Relevance": answer_relevance(question, pred),
            "Diversity": diversity_score(pred),
            "Answer Length": len(pred.split()),
            "Ground Truth Length": len(ref.split())
        }

        results.append(metrics)

    return pd.DataFrame(results)


def load_data(filepath):
    """Hàm load dữ liệu từ CSV"""
    df = pd.read_csv(filepath)
    data = []
    for _, item in df.iterrows():
        dt = {
            "question": item["question"],
            "contexts": [item["context_retriever_llama"]],
            "answer": item["response_llama"],
            "ground_truth": item["answer"]
        }
        data.append(dt)
    return data


if __name__ == "__main__":
    filepath = "E:/source_code/nlp/med_studio/data_sample_50_predicted.csv"
    data = load_data(filepath)

    evaluation_data = data

    results_df = evaluate_rag_simple(evaluation_data)

    avg_scores = results_df.mean(numeric_only=True)

    results_df.to_csv("eval_v2_llama.csv", index=False)

    print("\nChi tiết đánh giá:")
    print(results_df)
    print("\nĐiểm trung bình các metrics:")
    print(avg_scores)
# Out:
# Chi tiết đánh giá:
#                                              Question  Context Relevance  \
# 0                       What is (are) Breast Cancer ?           0.652565
# 1       What are the symptoms of Genochondromatosis ?           0.825076
# 2                         What causes Pars planitis ?           0.840998
# 3   What are the genetic changes related to genito...           0.710824
# 4   What are the treatments for Pseudopelade of Br...           0.816476
# 5                  What is (are) Preauricular sinus ?           0.801746
# 6   How many people are affected by capillary malf...           0.678636
# 7                      What is (are) Drug Reactions ?           0.565405
# 8                      What is (are) Ollier disease ?           0.856656
# 9                                  What causes ARDS ?           0.886695
# 10  What is (are) carnitine-acylcarnitine transloc...           0.820138
# 11  How many people are affected by spondylocostal...           0.778148
# 12                       What is (are) Hearing Loss ?           0.787851
# 13   What is (are) Age-related Macular Degeneration ?           0.826646
# 14     What is (are) Benign Essential Blepharospasm ?           0.706934
# 15                    What is (are) Pycnodysostosis ?           0.850926
# 16             What are the treatments for Melanoma ?           0.725694
# 17  What are the symptoms of Common variable immun...           0.581861
# 18  What are the symptoms of Chronic atypical neut...           0.807631
# 19           What is (are) Chronic Fatigue Syndrome ?           0.779576
# 20     What is (are) molybdenum cofactor deficiency ?           0.790496
# 21                              How to prevent COPD ?           0.829418
# 22                      What causes Turner syndrome ?           0.804036
# 23  What are the treatments for Chronic Neutrophil...           0.722259
# 24            What is (are) Familial stomach cancer ?           0.896596
# 25  Is inclusion body myopathy with early-onset Pa...           0.787375
# 26    What are the treatments for Anxiety Disorders ?           0.715099
# 27                What causes Merkel cell carcinoma ?           0.887770
# 28        What is (are) Pigment-dispersion syndrome ?           0.855905
# 29          What are the symptoms of Dent disease 1 ?           0.690022
# 30  What are the treatments for acute promyelocyti...           0.766764
# 31  What are the genetic changes related to Buschk...           0.848023
# 32  What are the genetic changes related to microp...           0.867061
# 33      Is benign essential blepharospasm inherited ?           0.726204
# 34  What are the genetic changes related to REN-re...           0.863983
# 35  what research (or clinical trials) is being do...           0.689608
# 36  How many people are affected by adenosine mono...           0.718216
# 37  What are the treatments for Glucose-6-phosphat...           0.847431
# 38  What are the genetic changes related to myoclo...           0.710908
# 39       What are the symptoms of Northern epilepsy ?           0.694114
# 40        Is Alpers-Huttenlocher syndrome inherited ?           0.669415
# 41     What is the outlook for Oropharyngeal Cancer ?           0.772572
# 42                   How to diagnose COACH syndrome ?           0.819782
# 43                  What is (are) Polycythemia Vera ?           0.826952
# 44  What to do for What I need to know about Kidne...           0.893464
# 45  what research (or clinical trials) is being do...           0.736742
# 46  What are the treatments for Hailey-Hailey dise...           0.830339
# 47  What are the genetic changes related to cap my...           0.708509
# 48             What are the treatments for Glaucoma ?           0.839326
# 49           What are the symptoms of Myelofibrosis ?           0.788951
#
#     Answer Relevance  Diversity  Answer Length  Ground Truth Length
# 0           0.590611   0.552106            451                   68
# 1           0.848552   0.756098             41                  244
# 2           0.840961   0.850000             80                  107
# 3           0.752809   0.607362            163                  157
# 4           0.821685   0.818182             44                  102
# 5           0.709372   0.734375             64                  121
# 6           0.740368   1.000000             15                   26
# 7           0.619543   0.703125             64                  205
# 8           0.841490   0.759259             54                   90
# 9           0.619919   0.763158             76                  101
# 10          0.809184   0.882353             68                  148
# 11          0.856093   0.765625             64                   12
# 12          0.639388   0.539906            213                  135
# 13          0.792682   0.718182            110                   42
# 14          0.683266   0.804878             41                  154
# 15          0.728657   0.734177             79                  118
# 16          0.689359   0.561611            422                 2664
# 17          0.574552   0.585443            316                  337
# 18          0.882261   0.822222             45                  404
# 19          0.738999   0.600985            203                  202
# 20          0.776224   0.761194            134                  159
# 21          0.696710   0.731959             97                  475
# 22          0.859390   0.849057             53                  229
# 23          0.805439   0.792208             77                  100
# 24          0.886402   0.771930             57                  144
# 25          0.875922   0.850746             67                   61
# 26          0.847548   0.733333            105                  102
# 27          0.825180   0.803030             66                  132
# 28          0.827369   0.821429             56                  220
# 29          0.767417   0.759494             79                  323
# 30          0.788969   0.737226            137                   98
# 31          0.841698   0.702381             84                  133
# 32          0.887323   0.592105             76                  214
# 33          0.920520   0.969697             33                   83
# 34          0.836994   0.566667             60                   79
# 35          0.589007   0.497159            352                   55
# 36          0.797468   0.911765             34                   47
# 37          0.821604   0.841270             63                   99
# 38          0.798333   0.678161             87                  129
# 39          0.736701   0.663265            196                  269
# 40          0.894998   0.869565             46                   51
# 41          0.805224   0.652439            164                  160
# 42          0.692244   0.872340             47                   61
# 43          0.579723   0.600917            218                  408
# 44          0.730688   0.592593            243                  255
# 45          0.790408   0.664706            170                  190
# 46          0.876481   0.750000             96                  154
# 47          0.774485   0.688889             90                  232
# 48          0.806631   0.750000             56                  314
# 49          0.839079   0.750000             64                  230
#
# Điểm trung bình các metrics:
# Context Relevance        0.777956
# Answer Relevance         0.775119
# Diversity                0.735691
# Answer Length          114.400000
# Ground Truth Length    212.860000
# dtype: float64

# %%
print("\nChi tiết đánh giá:")
print(results_df)
# Out:
# Chi tiết đánh giá:
#                                              Question  Context Relevance  \
# 0                       What is (are) Breast Cancer ?           0.652565
# 1       What are the symptoms of Genochondromatosis ?           0.825076
# 2                         What causes Pars planitis ?           0.840998
# 3   What are the genetic changes related to genito...           0.710824
# 4   What are the treatments for Pseudopelade of Br...           0.816476
# 5                  What is (are) Preauricular sinus ?           0.801746
# 6   How many people are affected by capillary malf...           0.678636
# 7                      What is (are) Drug Reactions ?           0.565405
# 8                      What is (are) Ollier disease ?           0.856656
# 9                                  What causes ARDS ?           0.886695
# 10  What is (are) carnitine-acylcarnitine transloc...           0.820138
# 11  How many people are affected by spondylocostal...           0.778148
# 12                       What is (are) Hearing Loss ?           0.787851
# 13   What is (are) Age-related Macular Degeneration ?           0.826646
# 14     What is (are) Benign Essential Blepharospasm ?           0.706934
# 15                    What is (are) Pycnodysostosis ?           0.850926
# 16             What are the treatments for Melanoma ?           0.725694
# 17  What are the symptoms of Common variable immun...           0.581861
# 18  What are the symptoms of Chronic atypical neut...           0.807631
# 19           What is (are) Chronic Fatigue Syndrome ?           0.779576
# 20     What is (are) molybdenum cofactor deficiency ?           0.790496
# 21                              How to prevent COPD ?           0.829418
# 22                      What causes Turner syndrome ?           0.804036
# 23  What are the treatments for Chronic Neutrophil...           0.722259
# 24            What is (are) Familial stomach cancer ?           0.896596
# 25  Is inclusion body myopathy with early-onset Pa...           0.787375
# 26    What are the treatments for Anxiety Disorders ?           0.715099
# 27                What causes Merkel cell carcinoma ?           0.887770
# 28        What is (are) Pigment-dispersion syndrome ?           0.855905
# 29          What are the symptoms of Dent disease 1 ?           0.690022
# 30  What are the treatments for acute promyelocyti...           0.766764
# 31  What are the genetic changes related to Buschk...           0.848023
# 32  What are the genetic changes related to microp...           0.867061
# 33      Is benign essential blepharospasm inherited ?           0.726204
# 34  What are the genetic changes related to REN-re...           0.863983
# 35  what research (or clinical trials) is being do...           0.689608
# 36  How many people are affected by adenosine mono...           0.718216
# 37  What are the treatments for Glucose-6-phosphat...           0.847431
# 38  What are the genetic changes related to myoclo...           0.710908
# 39       What are the symptoms of Northern epilepsy ?           0.694114
# 40        Is Alpers-Huttenlocher syndrome inherited ?           0.669415
# 41     What is the outlook for Oropharyngeal Cancer ?           0.772572
# 42                   How to diagnose COACH syndrome ?           0.819782
# 43                  What is (are) Polycythemia Vera ?           0.826952
# 44  What to do for What I need to know about Kidne...           0.893464
# 45  what research (or clinical trials) is being do...           0.736742
# 46  What are the treatments for Hailey-Hailey dise...           0.830339
# 47  What are the genetic changes related to cap my...           0.708509
# 48             What are the treatments for Glaucoma ?           0.839326
# 49           What are the symptoms of Myelofibrosis ?           0.788951
#
#     Answer Relevance  Diversity  Answer Length  Ground Truth Length
# 0           0.590611   0.552106            451                   68
# 1           0.848552   0.756098             41                  244
# 2           0.840961   0.850000             80                  107
# 3           0.752809   0.607362            163                  157
# 4           0.821685   0.818182             44                  102
# 5           0.709372   0.734375             64                  121
# 6           0.740368   1.000000             15                   26
# 7           0.619543   0.703125             64                  205
# 8           0.841490   0.759259             54                   90
# 9           0.619919   0.763158             76                  101
# 10          0.809184   0.882353             68                  148
# 11          0.856093   0.765625             64                   12
# 12          0.639388   0.539906            213                  135
# 13          0.792682   0.718182            110                   42
# 14          0.683266   0.804878             41                  154
# 15          0.728657   0.734177             79                  118
# 16          0.689359   0.561611            422                 2664
# 17          0.574552   0.585443            316                  337
# 18          0.882261   0.822222             45                  404
# 19          0.738999   0.600985            203                  202
# 20          0.776224   0.761194            134                  159
# 21          0.696710   0.731959             97                  475
# 22          0.859390   0.849057             53                  229
# 23          0.805439   0.792208             77                  100
# 24          0.886402   0.771930             57                  144
# 25          0.875922   0.850746             67                   61
# 26          0.847548   0.733333            105                  102
# 27          0.825180   0.803030             66                  132
# 28          0.827369   0.821429             56                  220
# 29          0.767417   0.759494             79                  323
# 30          0.788969   0.737226            137                   98
# 31          0.841698   0.702381             84                  133
# 32          0.887323   0.592105             76                  214
# 33          0.920520   0.969697             33                   83
# 34          0.836994   0.566667             60                   79
# 35          0.589007   0.497159            352                   55
# 36          0.797468   0.911765             34                   47
# 37          0.821604   0.841270             63                   99
# 38          0.798333   0.678161             87                  129
# 39          0.736701   0.663265            196                  269
# 40          0.894998   0.869565             46                   51
# 41          0.805224   0.652439            164                  160
# 42          0.692244   0.872340             47                   61
# 43          0.579723   0.600917            218                  408
# 44          0.730688   0.592593            243                  255
# 45          0.790408   0.664706            170                  190
# 46          0.876481   0.750000             96                  154
# 47          0.774485   0.688889             90                  232
# 48          0.806631   0.750000             56                  314
# 49          0.839079   0.750000             64                  230

# %%
results_df
# Out:
#                                              Question  Context Relevance  \
# 0                       What is (are) Breast Cancer ?           0.652565
# 1       What are the symptoms of Genochondromatosis ?           0.825076
# 2                         What causes Pars planitis ?           0.840998
# 3   What are the genetic changes related to genito...           0.710824
# 4   What are the treatments for Pseudopelade of Br...           0.816476
# 5                  What is (are) Preauricular sinus ?           0.801746
# 6   How many people are affected by capillary malf...           0.678636
# 7                      What is (are) Drug Reactions ?           0.565405
# 8                      What is (are) Ollier disease ?           0.856656
# 9                                  What causes ARDS ?           0.886695
# 10  What is (are) carnitine-acylcarnitine transloc...           0.820138
# 11  How many people are affected by spondylocostal...           0.778148
# 12                       What is (are) Hearing Loss ?           0.787851
# 13   What is (are) Age-related Macular Degeneration ?           0.826646
# 14     What is (are) Benign Essential Blepharospasm ?           0.706934
# 15                    What is (are) Pycnodysostosis ?           0.850926
# 16             What are the treatments for Melanoma ?           0.725694
# 17  What are the symptoms of Common variable immun...           0.581861
# 18  What are the symptoms of Chronic atypical neut...           0.807631
# 19           What is (are) Chronic Fatigue Syndrome ?           0.779576
# 20     What is (are) molybdenum cofactor deficiency ?           0.790496
# 21                              How to prevent COPD ?           0.829418
# 22                      What causes Turner syndrome ?           0.804036
# 23  What are the treatments for Chronic Neutrophil...           0.722259
# 24            What is (are) Familial stomach cancer ?           0.896596
# 25  Is inclusion body myopathy with early-onset Pa...           0.787375
# 26    What are the treatments for Anxiety Disorders ?           0.715099
# 27                What causes Merkel cell carcinoma ?           0.887770
# 28        What is (are) Pigment-dispersion syndrome ?           0.855905
# 29          What are the symptoms of Dent disease 1 ?           0.690022
# 30  What are the treatments for acute promyelocyti...           0.766764
# 31  What are the genetic changes related to Buschk...           0.848023
# 32  What are the genetic changes related to microp...           0.867061
# 33      Is benign essential blepharospasm inherited ?           0.726204
# 34  What are the genetic changes related to REN-re...           0.863983
# 35  what research (or clinical trials) is being do...           0.689608
# 36  How many people are affected by adenosine mono...           0.718216
# 37  What are the treatments for Glucose-6-phosphat...           0.847431
# 38  What are the genetic changes related to myoclo...           0.710908
# 39       What are the symptoms of Northern epilepsy ?           0.694114
# 40        Is Alpers-Huttenlocher syndrome inherited ?           0.669415
# 41     What is the outlook for Oropharyngeal Cancer ?           0.772572
# 42                   How to diagnose COACH syndrome ?           0.819782
# 43                  What is (are) Polycythemia Vera ?           0.826952
# 44  What to do for What I need to know about Kidne...           0.893464
# 45  what research (or clinical trials) is being do...           0.736742
# 46  What are the treatments for Hailey-Hailey dise...           0.830339
# 47  What are the genetic changes related to cap my...           0.708509
# 48             What are the treatments for Glaucoma ?           0.839326
# 49           What are the symptoms of Myelofibrosis ?           0.788951
#
#     Answer Relevance  Diversity  Answer Length  Ground Truth Length
# 0           0.590611   0.552106            451                   68
# 1           0.848552   0.756098             41                  244
# 2           0.840961   0.850000             80                  107
# 3           0.752809   0.607362            163                  157
# 4           0.821685   0.818182             44                  102
# 5           0.709372   0.734375             64                  121
# 6           0.740368   1.000000             15                   26
# 7           0.619543   0.703125             64                  205
# 8           0.841490   0.759259             54                   90
# 9           0.619919   0.763158             76                  101
# 10          0.809184   0.882353             68                  148
# 11          0.856093   0.765625             64                   12
# 12          0.639388   0.539906            213                  135
# 13          0.792682   0.718182            110                   42
# 14          0.683266   0.804878             41                  154
# 15          0.728657   0.734177             79                  118
# 16          0.689359   0.561611            422                 2664
# 17          0.574552   0.585443            316                  337
# 18          0.882261   0.822222             45                  404
# 19          0.738999   0.600985            203                  202
# 20          0.776224   0.761194            134                  159
# 21          0.696710   0.731959             97                  475
# 22          0.859390   0.849057             53                  229
# 23          0.805439   0.792208             77                  100
# 24          0.886402   0.771930             57                  144
# 25          0.875922   0.850746             67                   61
# 26          0.847548   0.733333            105                  102
# 27          0.825180   0.803030             66                  132
# 28          0.827369   0.821429             56                  220
# 29          0.767417   0.759494             79                  323
# 30          0.788969   0.737226            137                   98
# 31          0.841698   0.702381             84                  133
# 32          0.887323   0.592105             76                  214
# 33          0.920520   0.969697             33                   83
# 34          0.836994   0.566667             60                   79
# 35          0.589007   0.497159            352                   55
# 36          0.797468   0.911765             34                   47
# 37          0.821604   0.841270             63                   99
# 38          0.798333   0.678161             87                  129
# 39          0.736701   0.663265            196                  269
# 40          0.894998   0.869565             46                   51
# 41          0.805224   0.652439            164                  160
# 42          0.692244   0.872340             47                   61
# 43          0.579723   0.600917            218                  408
# 44          0.730688   0.592593            243                  255
# 45          0.790408   0.664706            170                  190
# 46          0.876481   0.750000             96                  154
# 47          0.774485   0.688889             90                  232
# 48          0.806631   0.750000             56                  314
# 49          0.839079   0.750000             64                  230

# %%
print("\nĐiểm trung bình các metrics:")
print(avg_scores)
# Out:
# Điểm trung bình các metrics:
# Context Relevance        0.777956
# Answer Relevance         0.775119
# Diversity                0.735691
# Answer Length          114.400000
# Ground Truth Length    212.860000
# dtype: float64

# %%
avg_scores
# Out:
# Context Relevance        0.777956
# Answer Relevance         0.775119
# Diversity                0.735691
# Answer Length          114.400000
# Ground Truth Length    212.860000
# dtype: float64

# %%
print("doneee ...")
# Out:
# doneee ...
