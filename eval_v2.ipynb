# %%
# !pip install pandas numpy nltk rouge-score bert-score sentence-transformers scikit-learn pycocoevalcap torch transformers

# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
from collections import Counter
import numpy as np

# Khởi tạo mô hình Sentence Transformer
model = SentenceTransformer('all-MiniLM-L6-v2')

def safe_convert_to_string(value):
    """Chuyển đổi giá trị đầu vào an toàn thành string"""
    if pd.isna(value) or value is None:
        return ""
    if isinstance(value, float):
        # Xử lý trường hợp đặc biệt khi giá trị là float
        if value.is_integer():
            return str(int(value))
        return str(value)
    return str(value)

def exact_match(pred, gt):
    """Tính Exact Match score"""
    pred = safe_convert_to_string(pred)
    gt = safe_convert_to_string(gt)
    return int(pred.strip().lower() == gt.strip().lower())

def word_f1(pred, gt):
    """Tính F1 score dựa trên từ"""
    pred = safe_convert_to_string(pred)
    gt = safe_convert_to_string(gt)
    
    pred_tokens = set(pred.lower().split())
    gt_tokens = set(gt.lower().split())
    
    common = pred_tokens & gt_tokens
    if len(pred_tokens) == 0 or len(gt_tokens) == 0:
        return 0.0
    
    precision = len(common) / len(pred_tokens)
    recall = len(common) / len(gt_tokens)
    
    if (precision + recall) == 0:
        return 0.0
    
    return 2 * (precision * recall) / (precision + recall)

def context_relevance(context, answer):
    """Tính độ liên quan giữa ngữ cảnh và câu trả lời"""
    context = safe_convert_to_string(context)
    answer = safe_convert_to_string(answer)
    
    if not context or not answer:
        return 0.0
    
    try:
        context_emb = model.encode(context)
        answer_emb = model.encode(answer)
        return float(cosine_similarity([context_emb], [answer_emb])[0][0])
    except:
        return 0.0

def answer_relevance(question, answer):
    """Tính độ liên quan giữa câu hỏi và câu trả lời"""
    question = safe_convert_to_string(question)
    answer = safe_convert_to_string(answer)
    
    if not question or not answer:
        return 0.0
    
    try:
        q_emb = model.encode(question)
        a_emb = model.encode(answer)
        return float(cosine_similarity([q_emb], [a_emb])[0][0])
    except:
        return 0.0

def diversity_score(text):
    """Tính độ đa dạng từ vựng"""
    text = safe_convert_to_string(text)
    try:
        tokens = text.lower().split()
        if not tokens:
            return 0.0
        unique_tokens = set(tokens)
        return len(unique_tokens) / len(tokens)
    except:
        return 0.0

def evaluate_rag_simple(data):
    """Hàm chính để đánh giá hệ thống RAG"""
    results = []
    
    for item in data:
        pred = item.get("answer", "")
        ref = item.get("ground_truth", "")
        context = item.get("contexts", [""])[0] if isinstance(item.get("contexts", []), list) else ""
        question = item.get("question", "")
        
        metrics = {
            "Question": question,
            # "Exact Match": exact_match(pred, ref),
            # "Word F1": word_f1(pred, ref),
            "Context Relevance": context_relevance(context, pred),
            "Answer Relevance": answer_relevance(question, pred),
            "Diversity": diversity_score(pred),
            "Answer Length": len(safe_convert_to_string(pred).split()),
            "Ground Truth Length": len(safe_convert_to_string(ref).split())
        }
        
        results.append(metrics)
    
    return pd.DataFrame(results)


def load_data(filepath):
    """Hàm load dữ liệu từ CSV"""
    df = pd.read_csv(filepath)
    data = []
    for _, item in df.iterrows():
        dt = {
            "question": item["question"],
            "contexts": [item["context_retriever_cohere"]],
            "answer": item["response_cohere"],
            "ground_truth": item["answer"]
        }
        data.append(dt)
    return data


if __name__ == "__main__":
    filepath = "E:/source_code/nlp/med_studio/data_sample_50_predicted.csv"
    data = load_data(filepath)

    evaluation_data = data

    results_df = evaluate_rag_simple(evaluation_data)

    avg_scores = results_df.mean(numeric_only=True)

    results_df.to_csv("eval_v2_cohere.csv", index=False)

    print("\nChi tiết đánh giá:")
    print(results_df)
    print("\nĐiểm trung bình các metrics:")
    print(avg_scores)
# Out:
# Chi tiết đánh giá:
#                                              Question  Context Relevance  \
# 0                       What is (are) Breast Cancer ?           0.725674
# 1       What are the symptoms of Genochondromatosis ?           0.816604
# 2                         What causes Pars planitis ?           0.868330
# 3   What are the genetic changes related to genito...           0.859980
# 4   What are the treatments for Pseudopelade of Br...           0.805402
# 5                  What is (are) Preauricular sinus ?           0.910615
# 6   How many people are affected by capillary malf...           0.760703
# 7                      What is (are) Drug Reactions ?           0.811457
# 8                      What is (are) Ollier disease ?           0.853164
# 9                                  What causes ARDS ?           0.856890
# 10  What is (are) carnitine-acylcarnitine transloc...           0.931598
# 11  How many people are affected by spondylocostal...           0.777715
# 12                       What is (are) Hearing Loss ?           0.726860
# 13   What is (are) Age-related Macular Degeneration ?           0.754004
# 14     What is (are) Benign Essential Blepharospasm ?           0.714922
# 15                    What is (are) Pycnodysostosis ?           0.800784
# 16             What are the treatments for Melanoma ?           0.000000
# 17  What are the symptoms of Common variable immun...           0.817157
# 18  What are the symptoms of Chronic atypical neut...           0.713200
# 19           What is (are) Chronic Fatigue Syndrome ?           0.796859
# 20     What is (are) molybdenum cofactor deficiency ?           0.828718
# 21                              How to prevent COPD ?           0.874663
# 22                      What causes Turner syndrome ?           0.826752
# 23  What are the treatments for Chronic Neutrophil...           0.752253
# 24            What is (are) Familial stomach cancer ?           0.890493
# 25  Is inclusion body myopathy with early-onset Pa...           0.807553
# 26    What are the treatments for Anxiety Disorders ?           0.840935
# 27                What causes Merkel cell carcinoma ?           0.809983
# 28        What is (are) Pigment-dispersion syndrome ?           0.984075
# 29          What are the symptoms of Dent disease 1 ?           0.793130
# 30  What are the treatments for acute promyelocyti...           0.546283
# 31  What are the genetic changes related to Buschk...           0.820941
# 32  What are the genetic changes related to microp...           0.839383
# 33      Is benign essential blepharospasm inherited ?           0.733698
# 34  What are the genetic changes related to REN-re...           0.888319
# 35  what research (or clinical trials) is being do...           0.830858
# 36  How many people are affected by adenosine mono...           0.730880
# 37  What are the treatments for Glucose-6-phosphat...           0.792427
# 38  What are the genetic changes related to myoclo...           0.900845
# 39       What are the symptoms of Northern epilepsy ?           0.647721
# 40        Is Alpers-Huttenlocher syndrome inherited ?           0.824148
# 41     What is the outlook for Oropharyngeal Cancer ?           0.926402
# 42                   How to diagnose COACH syndrome ?           0.810335
# 43                  What is (are) Polycythemia Vera ?           0.922714
# 44  What to do for What I need to know about Kidne...           0.871251
# 45  what research (or clinical trials) is being do...           0.043099
# 46  What are the treatments for Hailey-Hailey dise...           0.840835
# 47  What are the genetic changes related to cap my...           0.656554
# 48             What are the treatments for Glaucoma ?           0.876144
# 49           What are the symptoms of Myelofibrosis ?           0.803881
#
#     Answer Relevance  Diversity  Answer Length  Ground Truth Length
# 0           0.707059   0.553299            197                   68
# 1           0.812790   0.743590             39                  244
# 2           0.832760   0.842105             76                  107
# 3           0.672646   0.841270             63                  157
# 4           0.859622   0.676471             68                  102
# 5           0.631521   0.752137            117                  121
# 6           0.899012   1.000000             14                   26
# 7           0.531261   0.810127             79                  205
# 8           0.826840   0.750000             84                   90
# 9           0.778448   0.677083             96                  101
# 10          0.807208   0.768421             95                  148
# 11          0.874029   0.884615             26                   12
# 12          0.646986   0.609626            187                  135
# 13          0.770056   0.666667             93                   42
# 14          0.632234   0.819444             72                  154
# 15          0.749647   0.758621             58                  118
# 16          0.000000   0.000000              0                 2664
# 17          0.610022   0.766082            171                  337
# 18          0.696234   0.681529            157                  404
# 19          0.693585   0.673469            196                  202
# 20          0.784599   0.638462            260                  159
# 21          0.746933   0.800000             65                  475
# 22          0.774351   0.675214            117                  229
# 23          0.835026   0.902439             41                  100
# 24          0.877616   0.800000             60                  144
# 25          0.920930   0.830189             53                   61
# 26          0.784865   0.696552            145                  102
# 27          0.734756   0.589286            112                  132
# 28          0.715016   0.618182            220                  220
# 29          0.734099   0.729927            137                  323
# 30          0.705996   0.711111             90                   98
# 31          0.787422   0.595745            188                  133
# 32          0.844550   0.811321             53                  214
# 33          0.864283   0.807692             52                   83
# 34          0.772359   0.651685             89                   79
# 35          0.893606   0.828571             70                   55
# 36          0.739611   0.771429             35                   47
# 37          0.637693   0.786517             89                   99
# 38          0.601713   0.633803            142                  129
# 39          0.700252   0.647303            241                  269
# 40          0.881038   0.760000             50                   51
# 41          0.783628   0.538462            195                  160
# 42          0.803596   0.792208             77                   61
# 43          0.673177   0.681818            198                  408
# 44          0.731688   0.608392            143                  255
# 45          0.099746   1.000000             10                  190
# 46          0.866800   0.767241            116                  154
# 47          0.706669   1.000000             11                  232
# 48          0.728678   0.586957            184                  314
# 49          0.740412   0.923077             26                  230
#
# Điểm trung bình các metrics:
# Context Relevance        0.780344
# Answer Relevance         0.730061
# Diversity                0.729163
# Answer Length          103.140000
# Ground Truth Length    212.860000
# dtype: float64

# %%
print("\nChi tiết đánh giá:")
print(results_df)
# Out:
# Chi tiết đánh giá:
#                                              Question  Context Relevance  \
# 0                       What is (are) Breast Cancer ?           0.725674
# 1       What are the symptoms of Genochondromatosis ?           0.816604
# 2                         What causes Pars planitis ?           0.868330
# 3   What are the genetic changes related to genito...           0.859980
# 4   What are the treatments for Pseudopelade of Br...           0.805402
# 5                  What is (are) Preauricular sinus ?           0.910615
# 6   How many people are affected by capillary malf...           0.760703
# 7                      What is (are) Drug Reactions ?           0.811457
# 8                      What is (are) Ollier disease ?           0.853164
# 9                                  What causes ARDS ?           0.856890
# 10  What is (are) carnitine-acylcarnitine transloc...           0.931598
# 11  How many people are affected by spondylocostal...           0.777715
# 12                       What is (are) Hearing Loss ?           0.726860
# 13   What is (are) Age-related Macular Degeneration ?           0.754004
# 14     What is (are) Benign Essential Blepharospasm ?           0.714922
# 15                    What is (are) Pycnodysostosis ?           0.800784
# 16             What are the treatments for Melanoma ?           0.000000
# 17  What are the symptoms of Common variable immun...           0.817157
# 18  What are the symptoms of Chronic atypical neut...           0.713200
# 19           What is (are) Chronic Fatigue Syndrome ?           0.796859
# 20     What is (are) molybdenum cofactor deficiency ?           0.828718
# 21                              How to prevent COPD ?           0.874663
# 22                      What causes Turner syndrome ?           0.826752
# 23  What are the treatments for Chronic Neutrophil...           0.752253
# 24            What is (are) Familial stomach cancer ?           0.890493
# 25  Is inclusion body myopathy with early-onset Pa...           0.807553
# 26    What are the treatments for Anxiety Disorders ?           0.840935
# 27                What causes Merkel cell carcinoma ?           0.809983
# 28        What is (are) Pigment-dispersion syndrome ?           0.984075
# 29          What are the symptoms of Dent disease 1 ?           0.793130
# 30  What are the treatments for acute promyelocyti...           0.546283
# 31  What are the genetic changes related to Buschk...           0.820941
# 32  What are the genetic changes related to microp...           0.839383
# 33      Is benign essential blepharospasm inherited ?           0.733698
# 34  What are the genetic changes related to REN-re...           0.888319
# 35  what research (or clinical trials) is being do...           0.830858
# 36  How many people are affected by adenosine mono...           0.730880
# 37  What are the treatments for Glucose-6-phosphat...           0.792427
# 38  What are the genetic changes related to myoclo...           0.900845
# 39       What are the symptoms of Northern epilepsy ?           0.647721
# 40        Is Alpers-Huttenlocher syndrome inherited ?           0.824148
# 41     What is the outlook for Oropharyngeal Cancer ?           0.926402
# 42                   How to diagnose COACH syndrome ?           0.810335
# 43                  What is (are) Polycythemia Vera ?           0.922714
# 44  What to do for What I need to know about Kidne...           0.871251
# 45  what research (or clinical trials) is being do...           0.043099
# 46  What are the treatments for Hailey-Hailey dise...           0.840835
# 47  What are the genetic changes related to cap my...           0.656554
# 48             What are the treatments for Glaucoma ?           0.876144
# 49           What are the symptoms of Myelofibrosis ?           0.803881
#
#     Answer Relevance  Diversity  Answer Length  Ground Truth Length
# 0           0.707059   0.553299            197                   68
# 1           0.812790   0.743590             39                  244
# 2           0.832760   0.842105             76                  107
# 3           0.672646   0.841270             63                  157
# 4           0.859622   0.676471             68                  102
# 5           0.631521   0.752137            117                  121
# 6           0.899012   1.000000             14                   26
# 7           0.531261   0.810127             79                  205
# 8           0.826840   0.750000             84                   90
# 9           0.778448   0.677083             96                  101
# 10          0.807208   0.768421             95                  148
# 11          0.874029   0.884615             26                   12
# 12          0.646986   0.609626            187                  135
# 13          0.770056   0.666667             93                   42
# 14          0.632234   0.819444             72                  154
# 15          0.749647   0.758621             58                  118
# 16          0.000000   0.000000              0                 2664
# 17          0.610022   0.766082            171                  337
# 18          0.696234   0.681529            157                  404
# 19          0.693585   0.673469            196                  202
# 20          0.784599   0.638462            260                  159
# 21          0.746933   0.800000             65                  475
# 22          0.774351   0.675214            117                  229
# 23          0.835026   0.902439             41                  100
# 24          0.877616   0.800000             60                  144
# 25          0.920930   0.830189             53                   61
# 26          0.784865   0.696552            145                  102
# 27          0.734756   0.589286            112                  132
# 28          0.715016   0.618182            220                  220
# 29          0.734099   0.729927            137                  323
# 30          0.705996   0.711111             90                   98
# 31          0.787422   0.595745            188                  133
# 32          0.844550   0.811321             53                  214
# 33          0.864283   0.807692             52                   83
# 34          0.772359   0.651685             89                   79
# 35          0.893606   0.828571             70                   55
# 36          0.739611   0.771429             35                   47
# 37          0.637693   0.786517             89                   99
# 38          0.601713   0.633803            142                  129
# 39          0.700252   0.647303            241                  269
# 40          0.881038   0.760000             50                   51
# 41          0.783628   0.538462            195                  160
# 42          0.803596   0.792208             77                   61
# 43          0.673177   0.681818            198                  408
# 44          0.731688   0.608392            143                  255
# 45          0.099746   1.000000             10                  190
# 46          0.866800   0.767241            116                  154
# 47          0.706669   1.000000             11                  232
# 48          0.728678   0.586957            184                  314
# 49          0.740412   0.923077             26                  230

# %%
results_df
# Out:
#                                              Question  Context Relevance  \
# 0                       What is (are) Breast Cancer ?           0.725674
# 1       What are the symptoms of Genochondromatosis ?           0.816604
# 2                         What causes Pars planitis ?           0.868330
# 3   What are the genetic changes related to genito...           0.859980
# 4   What are the treatments for Pseudopelade of Br...           0.805402
# 5                  What is (are) Preauricular sinus ?           0.910615
# 6   How many people are affected by capillary malf...           0.760703
# 7                      What is (are) Drug Reactions ?           0.811457
# 8                      What is (are) Ollier disease ?           0.853164
# 9                                  What causes ARDS ?           0.856890
# 10  What is (are) carnitine-acylcarnitine transloc...           0.931598
# 11  How many people are affected by spondylocostal...           0.777715
# 12                       What is (are) Hearing Loss ?           0.726860
# 13   What is (are) Age-related Macular Degeneration ?           0.754004
# 14     What is (are) Benign Essential Blepharospasm ?           0.714922
# 15                    What is (are) Pycnodysostosis ?           0.800784
# 16             What are the treatments for Melanoma ?           0.000000
# 17  What are the symptoms of Common variable immun...           0.817157
# 18  What are the symptoms of Chronic atypical neut...           0.713200
# 19           What is (are) Chronic Fatigue Syndrome ?           0.796859
# 20     What is (are) molybdenum cofactor deficiency ?           0.828718
# 21                              How to prevent COPD ?           0.874663
# 22                      What causes Turner syndrome ?           0.826752
# 23  What are the treatments for Chronic Neutrophil...           0.752253
# 24            What is (are) Familial stomach cancer ?           0.890493
# 25  Is inclusion body myopathy with early-onset Pa...           0.807553
# 26    What are the treatments for Anxiety Disorders ?           0.840935
# 27                What causes Merkel cell carcinoma ?           0.809983
# 28        What is (are) Pigment-dispersion syndrome ?           0.984075
# 29          What are the symptoms of Dent disease 1 ?           0.793130
# 30  What are the treatments for acute promyelocyti...           0.546283
# 31  What are the genetic changes related to Buschk...           0.820941
# 32  What are the genetic changes related to microp...           0.839383
# 33      Is benign essential blepharospasm inherited ?           0.733698
# 34  What are the genetic changes related to REN-re...           0.888319
# 35  what research (or clinical trials) is being do...           0.830858
# 36  How many people are affected by adenosine mono...           0.730880
# 37  What are the treatments for Glucose-6-phosphat...           0.792427
# 38  What are the genetic changes related to myoclo...           0.900845
# 39       What are the symptoms of Northern epilepsy ?           0.647721
# 40        Is Alpers-Huttenlocher syndrome inherited ?           0.824148
# 41     What is the outlook for Oropharyngeal Cancer ?           0.926402
# 42                   How to diagnose COACH syndrome ?           0.810335
# 43                  What is (are) Polycythemia Vera ?           0.922714
# 44  What to do for What I need to know about Kidne...           0.871251
# 45  what research (or clinical trials) is being do...           0.043099
# 46  What are the treatments for Hailey-Hailey dise...           0.840835
# 47  What are the genetic changes related to cap my...           0.656554
# 48             What are the treatments for Glaucoma ?           0.876144
# 49           What are the symptoms of Myelofibrosis ?           0.803881
#
#     Answer Relevance  Diversity  Answer Length  Ground Truth Length
# 0           0.707059   0.553299            197                   68
# 1           0.812790   0.743590             39                  244
# 2           0.832760   0.842105             76                  107
# 3           0.672646   0.841270             63                  157
# 4           0.859622   0.676471             68                  102
# 5           0.631521   0.752137            117                  121
# 6           0.899012   1.000000             14                   26
# 7           0.531261   0.810127             79                  205
# 8           0.826840   0.750000             84                   90
# 9           0.778448   0.677083             96                  101
# 10          0.807208   0.768421             95                  148
# 11          0.874029   0.884615             26                   12
# 12          0.646986   0.609626            187                  135
# 13          0.770056   0.666667             93                   42
# 14          0.632234   0.819444             72                  154
# 15          0.749647   0.758621             58                  118
# 16          0.000000   0.000000              0                 2664
# 17          0.610022   0.766082            171                  337
# 18          0.696234   0.681529            157                  404
# 19          0.693585   0.673469            196                  202
# 20          0.784599   0.638462            260                  159
# 21          0.746933   0.800000             65                  475
# 22          0.774351   0.675214            117                  229
# 23          0.835026   0.902439             41                  100
# 24          0.877616   0.800000             60                  144
# 25          0.920930   0.830189             53                   61
# 26          0.784865   0.696552            145                  102
# 27          0.734756   0.589286            112                  132
# 28          0.715016   0.618182            220                  220
# 29          0.734099   0.729927            137                  323
# 30          0.705996   0.711111             90                   98
# 31          0.787422   0.595745            188                  133
# 32          0.844550   0.811321             53                  214
# 33          0.864283   0.807692             52                   83
# 34          0.772359   0.651685             89                   79
# 35          0.893606   0.828571             70                   55
# 36          0.739611   0.771429             35                   47
# 37          0.637693   0.786517             89                   99
# 38          0.601713   0.633803            142                  129
# 39          0.700252   0.647303            241                  269
# 40          0.881038   0.760000             50                   51
# 41          0.783628   0.538462            195                  160
# 42          0.803596   0.792208             77                   61
# 43          0.673177   0.681818            198                  408
# 44          0.731688   0.608392            143                  255
# 45          0.099746   1.000000             10                  190
# 46          0.866800   0.767241            116                  154
# 47          0.706669   1.000000             11                  232
# 48          0.728678   0.586957            184                  314
# 49          0.740412   0.923077             26                  230

# %%
print("\nĐiểm trung bình các metrics:")
print(avg_scores)
# Out:
# Điểm trung bình các metrics:
# Context Relevance        0.780344
# Answer Relevance         0.730061
# Diversity                0.729163
# Answer Length          103.140000
# Ground Truth Length    212.860000
# dtype: float64

# %%
avg_scores
# Out:
# Context Relevance        0.780344
# Answer Relevance         0.730061
# Diversity                0.729163
# Answer Length          103.140000
# Ground Truth Length    212.860000
# dtype: float64

# %%
print("doneee ...")
# Out:
# doneee ...
